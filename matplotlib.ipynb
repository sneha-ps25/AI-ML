# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (2.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\HP\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
x=[1,2,3,4]

# %%
y=[10,20,25,30]

# %%
plt.plot(x,y)

# %%
plt.show()

# %%
plt.plot(x,y,color='green',linestyle='--',marker='o')

# %%
plt.title('My Plot')
# Out:
# Text(0.5, 1.0, 'My Plot')

# %%
plt.xlabel('X-axis')
# Out:
# Text(0.5, 0, 'X-axis')

# %%
plt.ylabel('Y-axis')
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
x=[1,2,3]

# %%
y1=[1,4,9]

# %%
y2=[1,2,3]

# %%
plt.plot(x,y1,label='Squares')

# %%
plt.plot(x,y2,label='Linear')

# %%
x = [1, 2, 3]
y1 = [1, 4, 9]
y2 = [1, 2, 3]
plt.plot(x, y1, label='Squares')
plt.plot(x, y2, label='Linear')
plt.legend()
plt.show()

# %%
categories=['A','B','C']
values=[5,7,3]
plt.bar(categories,values)
plt.show()

# %%
data=[1,1,2,3,3,3,4,4,5]
plt.hist(data,bins=5)
plt.show()

# %%
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]
plt.scatter(x, y)
plt.show()

# %%
plt.subplot(1, 2, 1)
plt.plot([1, 2, 3], [1, 2, 3])
plt.subplot(1, 2, 2)
plt.plot([1, 2, 3], [3, 2, 1])
plt.show()

# %%
plt
